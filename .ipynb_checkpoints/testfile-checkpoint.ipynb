# %%
from Fittness.calories_burn import monitoring
from Fittness.calories_burn import records




name = input("Please Enter name: ")
gender = input("Please Enter your gender (female or male): ")
age= int(input("Please Enter your age (integer): "))
height= int(input("Please Enter your height in cm: "  ))
weight= int(input("Please Enter your weight in kg: "))



P1=records.Records(name,gender,age,height,weight)
P1.display()
P1.BMI()
P1.BMR()
P1.totalcal()



print("You could calculate your burned calories for today from Records.totalcal")
calory=float(input("Please Enter your calory in kcal: "))


M1=monitoring.Monitoring(name,gender,age,height,weight,calory)
M1.new_weight(55)
M1.new_calory(1893)
M1.new_weight(56.4)
M1.new_calory(1993)
M1.new_weight(57.4)
M1.new_calory(1893)
M1.new_weight(58.4)
M1.new_calory(1893)
M1.new_weight(58.4)
M1.weight_calory_plot()
M1.weight_change_plot()
M1.calory_change_plot()
# Out:
# Please Enter name:  yuxuan
# Please Enter your gender (female or male):  female
# Please Enter your age (integer):  22
# Please Enter your height in cm:  174
# Please Enter your weight in kg:  55
# Name: yuxuan Age: 22 Gender:female Height: 174cm Wegiht: 55kg
# Hello,yuxuan your BMI is 18.17 which is in underweight range
# Hello,yuxuan your BMR is around 1392.8 Kcal/day
# Did you do any exercises today (Yes/No):  yes
# please check your answer, please either enter Yes or No
# Did you do any exercises today (Yes/No):  yes
# please check your answer, please either enter Yes or No
# Did you do any exercises today (Yes/No):  Yes
# Intensity has three levels= 3(Light),4(Moderate),7(Vigorous) please enter your level:  7
# Please Enter exercise time in minutes:   300
# please check your answer, please either enter Yes or No
# Hello,the total burned calories for today is 3414 Kcal
# You could calculate your burned calories for today from Records.totalcal
# Please Enter your calory in kcal:  3414
